# %%
import numpy as np


import importlib

def version_check(libname, min_version):
    m = importlib.import_module(libname)
    print "%s version %s is" % (libname, m.__version__),
    print ("OK" if m.__version__ >= min_version 
           else "out-of-date. Please upgrade!")
    
version_check("numpy", "1.11")
version_check("matplotlib", "1.5")
version_check("pandas", "0.18")
version_check("nltk", "3.2")
#version_check("tensorflow", "0.12.1")

import csv
import copy
# Out:
# numpy version 1.13.3 is OK
# matplotlib version 2.0.2 is OK
# pandas version 0.20.3 is OK
# nltk version 3.2.5 is OK

# %%
file_list = open('../SampleData/2014_Data/all_inventors_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2014_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1    

all_inventors_2014 = np.array(data)
all_inventor_header_2014 = header

i=0
for head in all_inventor_header_2014:
    print "2014 All Inventors Header Index->", i, head
    i=i+1
# Out:
# 2014 All Inventors Header Index-> 0 application_number
# 2014 All Inventors Header Index-> 1 inventor_name_first
# 2014 All Inventors Header Index-> 2 inventor_name_middle
# 2014 All Inventors Header Index-> 3 inventor_name_last
# 2014 All Inventors Header Index-> 4 inventor_rank
# 2014 All Inventors Header Index-> 5 inventor_region_code
# 2014 All Inventors Header Index-> 6 inventor_country_code
# 2014 All Inventors Header Index-> 7 inventor_country_name
# 2014 All Inventors Header Index-> 8 inventor_address_type

# %%
file_list = open('../SampleData/2014_Data/application_data_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2014_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
all_application_data_2014 = data
all_application_data_header_2014 = header

i=0
for head in all_application_data_header_2014:
    print "2014 All Application Data Header Index->", i, head
    i=i+1
# Out:
# 2014 All Application Data Header Index-> 0 application_number
# 2014 All Application Data Header Index-> 1 filing_date
# 2014 All Application Data Header Index-> 2 invention_subject_matter
# 2014 All Application Data Header Index-> 3 application_type
# 2014 All Application Data Header Index-> 4 examiner_name_last
# 2014 All Application Data Header Index-> 5 examiner_name_first
# 2014 All Application Data Header Index-> 6 examiner_name_middle
# 2014 All Application Data Header Index-> 7 examiner_id
# 2014 All Application Data Header Index-> 8 examiner_art_unit
# 2014 All Application Data Header Index-> 9 uspc_class
# 2014 All Application Data Header Index-> 10 uspc_subclass
# 2014 All Application Data Header Index-> 11 confirm_number
# 2014 All Application Data Header Index-> 12 customer_number
# 2014 All Application Data Header Index-> 13 atty_docket_number
# 2014 All Application Data Header Index-> 14 appl_status_code
# 2014 All Application Data Header Index-> 15 appl_status_date
# ...

# %%
file_list = open('../SampleData/2014_Data/continuity_children_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2014_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
continuity_children_2014 = data
continuity_children_header_2014 = header

i=0
for head in continuity_children_header_2014:
    print "2014 Continuity Childern Header Index->", i, head
    i=i+1
# Out:
# 2014 Continuity Childern Header Index-> 0 application_number
# 2014 Continuity Childern Header Index-> 1 child_application_number
# 2014 Continuity Childern Header Index-> 2 child_filing_date
# 2014 Continuity Childern Header Index-> 3 continuation_type

# %%
file_list = open('../SampleData/2014_Data/continuity_parents_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2014_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
continuity_parents_2014 = data
continuity_parents_header_2014 = header

i=0
for head in continuity_parents_header_2014:
    print "2014 Continuity Parents Header Index->", i, head
    i=i+1
# Out:
# 2014 Continuity Parents Header Index-> 0 application_number
# 2014 Continuity Parents Header Index-> 1 parent_application_number
# 2014 Continuity Parents Header Index-> 2 parent_filing_date
# 2014 Continuity Parents Header Index-> 3 continuation_type

# %%
file_list = open('../SampleData/2014_Data/foreign_priority_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2014_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
foreign_priority_2014 = data
foreign_priority_header_2014 = header

i=0
for head in foreign_priority_header_2014:
    print "2014 Foreign Priority Header Index->", i, head
    i=i+1

# %%
file_list = open('../SampleData/2015_Data/all_inventors_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2015_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1    

all_inventors_2015 = np.array(data)
all_inventor_header_2015 = header

i=0
for head in all_inventor_header_2015:
    print "2015 All Inventors Header Index->", i, head
    i=i+1

# %%
file_list = open('../SampleData/2015_Data/application_data_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2015_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
all_application_data_2015 = data
all_application_data_header_2015 = header

i=0
for head in all_application_data_header_2015:
    print "2015 All Application Data Header Index->", i, head
    i=i+1

# %%
file_list = open('../SampleData/2015_Data/continuity_children_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2015_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
continuity_children_2015 = data
continuity_children_header_2015 = header

i=0
for head in continuity_children_header_2015:
    print "2015 Continuity Childern Header Index->", i, head
    i=i+1

# %%
file_list = open('../SampleData/2015_Data/continuity_parents_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2015_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
continuity_parents_2015 = data
continuity_parents_header_2015 = header

i=0
for head in continuity_parents_header_2015:
    print "2015 Continuity Parents Header Index->", i, head
    i=i+1

# %%
file_list = open('../SampleData/2015_Data/foreign_priority_list', 'r')
file_number = 0
data = []
data_each_file = []

for line in file_list:  
    filename = "../SampleData/2015_Data/" + line.strip('\n') 
    #print filename
    with open(filename, 'rb') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        
        # If it is not the first file we need to skip the header
        if (file_number > 0):
            next(csvreader)
        i = 0 
        
        for row in csvreader:
            # If it is the first file store the header
            if ( (file_number==0) and (i==0) ):
                header = row
            else:
                data.append(row)
            
            i = i + 1
    if ( file_number==0 ):
        data_each_file.append(i-1)
    else:
        data_each_file.append(i)
        
    
    file_number = file_number + 1
    
data = np.array(data)
foreign_priority_2015 = data
foreign_priority_header_2015 = header

i=0
for head in foreign_priority_header_2015:
    print "2015 Foreign Priority Header Index->", i, head
    i=i+1
